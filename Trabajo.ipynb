# %%
#actividad 1: 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_2021 = pd.read_csv("df_2021_new.csv")
df_2021
# Out:
# /var/folders/xx/8ljg54gs66gdzlm3grgkg2vr0000gn/T/ipykernel_1436/3330143858.py:1: DtypeWarning: Columns (25,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2021 = pd.read_csv("df_2021_new.csv")
#          AGNO    RBD  DGV_RBD                  NOM_RBD  COD_REG_RBD  \
# 0        2021      1        9  LICEO POLITECNICO ARICA           15
# 1        2021      1        9  LICEO POLITECNICO ARICA           15
# 2        2021      1        9  LICEO POLITECNICO ARICA           15
# 3        2021      1        9  LICEO POLITECNICO ARICA           15
# 4        2021      1        9  LICEO POLITECNICO ARICA           15
# ...       ...    ...      ...                      ...          ...
# 3626451  2021  41899        4        COLEGIO SAN JORGE            8
# 3626452  2021  41899        4        COLEGIO SAN JORGE            8
# 3626453  2021  41899        4        COLEGIO SAN JORGE            8
# ...

# %%
df_2022 = pd.read_csv("df_2022_new.csv")
df_2022
# Out:
# /var/folders/xx/8ljg54gs66gdzlm3grgkg2vr0000gn/T/ipykernel_1436/2193284039.py:1: DtypeWarning: Columns (25,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2022 = pd.read_csv("df_2022_new.csv")
#          AGNO    RBD  DGV_RBD  \
# 0        2022      1        9
# 1        2022      1        9
# 2        2022      1        9
# 3        2022      1        9
# 4        2022      1        9
# ...       ...    ...      ...
# 3644543  2022  42071        9
# 3644544  2022  42071        9
# 3644545  2022  42071        9
# 3644546  2022  42081        6
# 3644547  2022  42081        6
#
#                                                   NOM_RBD  COD_REG_RBD  \
# 0                                 LICEO POLITECNICO ARICA           15
# 1                                 LICEO POLITECNICO ARICA           15
# 2                                 LICEO POLITECNICO ARICA           15
# 3                                 LICEO POLITECNICO ARICA           15
# ...

# %%
Conectar_bases = pd.concat([df_2021, df_2022 ], axis=0)
Conectar_bases_SD= Conectar_bases.drop_duplicates()
display(len(Conectar_bases)-len(Conectar_bases_SD))
# Out:
# 0

# %% [markdown]
# Debe responder las siguientes preguntas
# 1. Presentar, a trav´es de una tabla de doble entrada, la cantidad por sexo segun la dependencia del establecimiento. Indique la fecuencia absoluta y relativa (20 puntos).

# %%
tabla1 = df_2021.groupby("NOM_COM_ALU")["NOM_COM_ALU"].agg(["count"])
tabla1
# Out:
#                  count
# NOM_COM_ALU
#                  21946
# ALGARROBO         2144
# ALHUÉ             1452
# ALTO BIOBÍO       1573
# ALTO DEL CARMEN    862
# ...                ...
# YUMBEL            3551
# YUNGAY            3217
# ZAPALLAR          1244
# ÑIQUÉN            2013
# ÑUÑOA            28476
#
# [347 rows x 1 columns]

# %%
regiones_deseadas = ['AYSEN', 'ARAUC']
df_filtrado = df[df['regiones'].isin(regiones_deseadas)]

df_filtrado.to_csv('df_2021_filtrado.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 regiones_deseadas = ['AYSEN', 'ARAUC']
# ----> 2 df_filtrado = df[df['regiones'].isin(regiones_deseadas)]
#       4 df_filtrado.to_csv('df_2021_filtrado.csv', index=False)
#
# NameError: name 'df' is not defined

# %%
conectarbases = pd.concat([df_2021, df_2022 ], axis=0)
conectarbases
# Out:
#          AGNO    RBD  DGV_RBD  \
# 0        2021      1        9
# 1        2021      1        9
# 2        2021      1        9
# 3        2021      1        9
# 4        2021      1        9
# ...       ...    ...      ...
# 3644543  2022  42071        9
# 3644544  2022  42071        9
# 3644545  2022  42071        9
# 3644546  2022  42081        6
# 3644547  2022  42081        6
#
#                                                   NOM_RBD  COD_REG_RBD  \
# 0                                 LICEO POLITECNICO ARICA           15
# 1                                 LICEO POLITECNICO ARICA           15
# 2                                 LICEO POLITECNICO ARICA           15
# 3                                 LICEO POLITECNICO ARICA           15
# 4                                 LICEO POLITECNICO ARICA           15
# ...                                                   ...          ...
# 3644543  INSTITUTO DE EDUCACIÓN DE ADULTOS MONTAÑA NEVADA           10
# ...

# %%
conectarbases[conectarbases["NOM_REG_RBD_A"].str.contains("AYSEN")|conectarbases["NOM_REG_RBD_A"].str.contains("ARAUC")]
# Out:
#          AGNO    RBD  DGV_RBD                     NOM_RBD  COD_REG_RBD  \
# 995327   2021   5215        9  LICEO INDUSTRIAL B-5 ANGOL            9
# 995328   2021   5215        9  LICEO INDUSTRIAL B-5 ANGOL            9
# 995329   2021   5215        9  LICEO INDUSTRIAL B-5 ANGOL            9
# 995330   2021   5215        9  LICEO INDUSTRIAL B-5 ANGOL            9
# 995331   2021   5215        9  LICEO INDUSTRIAL B-5 ANGOL            9
# ...       ...    ...      ...                         ...          ...
# 3643933  2022  41931        1  ESCUELA DE LENGUAJE RENACE            9
# 3643934  2022  41931        1  ESCUELA DE LENGUAJE RENACE            9
# 3643935  2022  41931        1  ESCUELA DE LENGUAJE RENACE            9
# 3643936  2022  41931        1  ESCUELA DE LENGUAJE RENACE            9
# 3643937  2022  41931        1  ESCUELA DE LENGUAJE RENACE            9
#
#         NOM_REG_RBD_A  COD_PRO_RBD  COD_COM_RBD NOM_COM_RBD  COD_DEPROV_RBD  \
# ...

# %%
base_2021[base_2021["NOM_REG_RBD_A"].str.contains("AYSEN")]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 base_2021[base_2021["NOM_REG_RBD_A"].str.contains("AYSEN")]
#
# NameError: name 'base_2021' is not defined

# %%
df_ejemplo1 = df_ejemplo.drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df_ejemplo1 = df_ejemplo.drop_duplicates()
#
# NameError: name 'df_ejemplo' is not defined

# %%
df_2021.agg.count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df_2021.agg.count()
#
# AttributeError: 'function' object has no attribute 'count'

# %%
df_new = pd.DataFrame(df_2021)
duplicados = df_new["MRUN"].duplicated(keep = False)
N_duplicados = duplicados.sum()
N_duplicados
# Out:
# 0

# %%
df_12=df_2021["MRUN"].drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_12=df_2021["MRUN"].drop_duplicates()
#       2 df_23.count()
#
# NameError: name 'df_2021' is not defined

# %%
#5
df_comuna= conectarbases[conectarbases['NOM_COM_RBD']=='ANGOL']
df_comuna=df_comuna[['RURAL_RBD','NOM_RBD']].drop_duplicates()
df_comuna['RURAL_RBD'] = df_comuna['RURAL_RBD'].replace(0, 'URBANO')
df_comuna['RURAL_RBD'] = df_comuna['RURAL_RBD'].replace(1, 'RURAL')


tabla= df_comuna.groupby('RURAL_RBD')['NOM_RBD'].agg(["count"])
tabla
# Out:
#            count
# RURAL_RBD
# RURAL          6
# URBANO        28
