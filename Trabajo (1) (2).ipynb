# %% [markdown]
# # Trabajo N°1, Grupo 1: Análisis Bases de Datos
#
# ### Integrantes: Oscar Alcaíno, Sebastían Cabello, Valentina Gomez, Ignacio Subiabre.
# ##### (XXI y IX Región) o (Región de Aysen y Araucania)

# %% [markdown]
# ## Fase 1:
# ###  a) Importamos las librerias y bases de datos

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
base_2021 = pd.read_csv("df_2021_new.csv")
base_2021
# Out:
# /var/folders/xx/8ljg54gs66gdzlm3grgkg2vr0000gn/T/ipykernel_1378/3344664742.py:1: DtypeWarning: Columns (25,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   base_2021 = pd.read_csv("df_2021_new.csv")
#          AGNO    RBD  DGV_RBD                  NOM_RBD  COD_REG_RBD  \
# 0        2021      1        9  LICEO POLITECNICO ARICA           15
# 1        2021      1        9  LICEO POLITECNICO ARICA           15
# 2        2021      1        9  LICEO POLITECNICO ARICA           15
# 3        2021      1        9  LICEO POLITECNICO ARICA           15
# 4        2021      1        9  LICEO POLITECNICO ARICA           15
# ...       ...    ...      ...                      ...          ...
# 3626451  2021  41899        4        COLEGIO SAN JORGE            8
# 3626452  2021  41899        4        COLEGIO SAN JORGE            8
# 3626453  2021  41899        4        COLEGIO SAN JORGE            8
# ...

# %%
base_2022 = pd.read_csv("df_2022_new.csv")
base_2022
# Out:
# /var/folders/xx/8ljg54gs66gdzlm3grgkg2vr0000gn/T/ipykernel_1378/4087446609.py:1: DtypeWarning: Columns (25,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   base_2022 = pd.read_csv("df_2022_new.csv")
#          AGNO    RBD  DGV_RBD  \
# 0        2022      1        9
# 1        2022      1        9
# 2        2022      1        9
# 3        2022      1        9
# 4        2022      1        9
# ...       ...    ...      ...
# 3644543  2022  42071        9
# 3644544  2022  42071        9
# 3644545  2022  42071        9
# 3644546  2022  42081        6
# 3644547  2022  42081        6
#
#                                                   NOM_RBD  COD_REG_RBD  \
# 0                                 LICEO POLITECNICO ARICA           15
# 1                                 LICEO POLITECNICO ARICA           15
# 2                                 LICEO POLITECNICO ARICA           15
# 3                                 LICEO POLITECNICO ARICA           15
# ...

# %% [markdown]
# ### b) Filtramos las bases de datos por región

# %%
base_filtrada_21 = base_2021[base_2021["NOM_REG_RBD_A"].str.contains("ARAUC")|base_2021["NOM_REG_RBD_A"].str.contains("AYSEN")]
base_filtrada_21
# Out:
#          AGNO    RBD  DGV_RBD                     NOM_RBD  COD_REG_RBD  \
# 995327   2021   5215        9  LICEO INDUSTRIAL B-5 ANGOL            9
# 995328   2021   5215        9  LICEO INDUSTRIAL B-5 ANGOL            9
# 995329   2021   5215        9  LICEO INDUSTRIAL B-5 ANGOL            9
# 995330   2021   5215        9  LICEO INDUSTRIAL B-5 ANGOL            9
# 995331   2021   5215        9  LICEO INDUSTRIAL B-5 ANGOL            9
# ...       ...    ...      ...                         ...          ...
# 3623285  2021  41701        7           COLEGIO PATAGONIA           11
# 3623286  2021  41701        7           COLEGIO PATAGONIA           11
# 3623287  2021  41701        7           COLEGIO PATAGONIA           11
# 3623288  2021  41701        7           COLEGIO PATAGONIA           11
# 3623289  2021  41701        7           COLEGIO PATAGONIA           11
#
#         NOM_REG_RBD_A  COD_PRO_RBD  COD_COM_RBD NOM_COM_RBD  COD_DEPROV_RBD  \
# ...

# %%
base_filtrada_22 = base_2022[base_2022["NOM_REG_RBD_A"].str.contains("AYSEN")|base_2022["NOM_REG_RBD_A"].str.contains("AYSEN")]
base_filtrada_22
# Out:
#          AGNO    RBD  DGV_RBD                            NOM_RBD  COD_REG_RBD  \
# 1305605  2022   8345        3  LICEO JOSEFINA AGUIRRE MONTENEGRO           11
# 1305606  2022   8345        3  LICEO JOSEFINA AGUIRRE MONTENEGRO           11
# 1305607  2022   8345        3  LICEO JOSEFINA AGUIRRE MONTENEGRO           11
# 1305608  2022   8345        3  LICEO JOSEFINA AGUIRRE MONTENEGRO           11
# 1305609  2022   8345        3  LICEO JOSEFINA AGUIRRE MONTENEGRO           11
# ...       ...    ...      ...                                ...          ...
# 3639036  2022  41701        7                  COLEGIO PATAGONIA           11
# 3639037  2022  41701        7                  COLEGIO PATAGONIA           11
# 3639038  2022  41701        7                  COLEGIO PATAGONIA           11
# 3639039  2022  41701        7                  COLEGIO PATAGONIA           11
# 3639040  2022  41701        7                  COLEGIO PATAGONIA           11
#
# ...

# %% [markdown]
# ###  c) Unimos ambas bases de datos mediante la función merge

# %%
Union_bases = pd.merge(base_filtrada_21, base_filtrada_22, how="inner", on=["COD_REG_RBD"])
Union_bases
#Union_bases, es ahora nuestro unido dataframe con df_2021 y df_2022 sin limpiar.
# Out:
# Canceled future for execute_request message before replies were done
# El Kernel se bloqueó al ejecutar código en la celda actual o en una celda anterior. Revise el código de las celdas para identificar una posible causa del error. Haga clic <a href='https://aka.ms/vscodeJupyterKernelCrash'>aquí</a> para obtener más información. Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %%
conectarbases= pd.concat()

# %% [markdown]
# ## Fase 2)
# ### Realizaremos la limpieza de la base de datos

# %%
conectarbases.isna().sum()

# %%
Sin_NA = conectarbases.dropna(subset = ["NOM_COM_RBD"])

Sin_NA.isna().sum()

# %% [markdown]
# #### Sin_NA está libre de celdas vacias

# %% [markdown]
# ## Fase 3)

# %% [markdown]
# ### Pregunta 1
# ####  Presentar a traves de una tabla de doble entrada, la cantidad por sexo segun la dependencia del establecimiento. Indique la fecuencia absoluta y relativa (20 puntos).

# %% [markdown]
# ### Pregunta 2
# #### a) Identificar e indicar en caso de existir, estudiantes cuyo dıgito verificador sea incorrecto. (25 puntos)

# %%
#comenzaremos buscando un posible rut
rut = 20163929
y = 0
num = 2
while rut>2:
    y+= rut%10*num
    rut = rut//10
    if num == 7:
        num = 2
    else : 
        num+=1
    facil= y//11 * 11
    dig_ver = 11-y+facil
    print(dig_ver)
#con la funcion podemos encontrar los posibles digitos verificador de los distintos rut.

# %% [markdown]
# #### b) Si, además, indica la comuna con mas errores de este tipo, suma (5 puntos).

# %% [markdown]
# ### Pregunta 3
#
# #### a) Resumir la variable edad de los alumnos, indicando: maximo, mınimo, y promedio. En caso de identificar valores erroneos o cuestionables, descartarlos y entregar el resumen sin estos alumnos. Describir y justificar esta decision junto a la respuesta. (20 puntos)

# %% [markdown]
# ### Pregunta 4
# #### a) Contar la cantidad de alumnos por comuna. (15 punto)

# %% [markdown]
# ### Pregunta 5
#
# #### a) En una comuna en particular (que deben decidir y declarar), indicar la cantidad de establecimientos ubicados en sectores rurales y urbanos. (15 puntos)

# %%
se hace con Dummys

# %% [markdown]
# ### Pregunta 6
#
# #### a)  Indicar la cantidad, de establecimientos que NO son municipales. (10 punto)

# %% [markdown]
# ### Pregunta 7
#
# #### a) Indicar la cantidad de estudiantes que nacieron en cada trimestre del año. (30 puntos)

# %% [markdown]
# ### Pregunta 8
#
# #### a) Indicar la cantidad de estudiantes que nacieron en cada trimestre del año. (30 puntos)

# %% [markdown]
# ### Pregunta 9
#
# #### a)  Indicar la distribucion segun porcentaje del tipo de jornada impartida. (15 puntos)
